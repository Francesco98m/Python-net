# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.set(style="darkgrid")
data_path = '/home/burrito/Documents/python/pytorch/Python-net/color_classifier/data_train_4.csv'
data = pd.read_csv(data_path)
data.head()
# Out:
#           x         y  color
# 0  0.684548  0.240450      2
# 1 -0.332662 -0.675847      0
# 2 -0.051252  0.092077      1
# 3 -0.717958  0.774152      1
# 4 -0.194950 -0.926658      0

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=data['x'], y=data['y'], hue=data['color'])

# %%
data_path_1 = '/home/burrito/Documents/python/pytorch/Python-net/color_classifier/pred_4.csv'
data_1 = pd.read_csv(data_path_1)
data_path_2 = '/home/burrito/Documents/python/pytorch/Python-net/color_classifier/data_test_4.csv'
data_2 = pd.read_csv(data_path_2)

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=data_2['x'], y=data_2['y'], hue=data_1['color']).set_title("Predictions")
# Out:
# Text(0.5, 1.0, 'Predictions')
