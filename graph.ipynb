# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data_path = '/home/burrito/Documents/python/pytorch/green_red/data.csv'
data = pd.read_csv(data_path)
data.head()
# Out:
#           x         y  color
# 0 -0.848912 -0.645967      0
# 1 -0.266424  0.794012      0
# 2  0.570036  0.032824      1
# 3 -0.744500  0.036838      0
# 4  0.496021  0.296731      1

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=data['x'], y=data['y'], hue=data['color'])

# %%
data_path_1 = '/home/burrito/Documents/python/pytorch/green_red/pred.csv'
data_1 = pd.read_csv(data_path_1)
data_path_2 = '/home/burrito/Documents/python/pytorch/green_red/data_test.csv'
data_2 = pd.read_csv(data_path_2)

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=data_2['x'], y=data_2['y'], hue=data_1['color'])
