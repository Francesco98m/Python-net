# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data_path = '/home/burrito/Documents/python/pytorch/green_red/data_train_4.csv'
data = pd.read_csv(data_path)
data.head()
# Out:
#           x         y  color
# 0 -0.634151  0.612270      1
# 1 -0.782661  0.718021      1
# 2 -0.336275  0.039677      0
# 3 -0.691231 -0.432010      0
# 4 -0.623175 -0.573305      0

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=data['x'], y=data['y'], hue=data['color'])

# %%
data_path_1 = '/home/burrito/Documents/python/pytorch/green_red/pred_4.csv'
data_1 = pd.read_csv(data_path_1)
data_path_2 = '/home/burrito/Documents/python/pytorch/green_red/data_test_4.csv'
data_2 = pd.read_csv(data_path_2)

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=data_2['x'], y=data_2['y'], hue=data_1['color'])
